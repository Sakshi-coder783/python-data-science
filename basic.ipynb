# %%
print('hello,world!')
# Out:
# hello,world!

# %% [markdown]
# Heading

# %% [markdown]
# #### heading

# %% [markdown]
# Heading
# -point1
# -point2

# %% [markdown]
# Heading
# - point1
#      -Subpoint1
#      -subpoint2
# - point2

# %% [markdown]
# Heading
# - point1
#     - subpoint1
#     - subpoint2
# - point2
